# %%
from moviepy.video.io.ffmpeg_tools import ffmpeg_extract_subclip

# %%
time0_walk = 35
timef_walk = 50

time0_run = 50
timef_run = 72

time0_jump = 72
timef_jump = 93

time0_legup = 93
timef_legup = 111

time0_pickup = 111
timef_pickup = 198

time0_walk2 = 198
timef_walk2 = 215

time0_highfall = 215
timef_highfall = 340

time0_sitandup = 370
timef_sitandup = 380

time0_movewithchair = 380
timef_movewithchair = 399

time0_fallchair = 399
timef_fallchair = 435

time0_upsitbed = 475
timef_upsitbed = 495

time0_uplyingbed = 495
timef_uplyingbed = 525

time0_fallbed = 525
timef_fallbed = 568


#walk,run,jump,legup,pickup,walk2,highfall,sitandup,movewithchair,fallchair,upsitbed,uplyingbed,fallbed

# %%
#path = "C:\Users\SuperSoso1\Cranfield\GDP\DATA\Test_data\KinectData\S1P19K"

actions = ['walk', 'run', 'jump', 'legup', 'pickup', 'walk2', 'highfall', 'sitandup', 'movewithchair', 'fallchair', 'upsitbed', 'uplyingbed', 'fallbed']
for a in actions :
    for i in range(1,8) :
        filename = "DATA/Test_data/KinectData/S2/S2P32K" + str(i) + ".avi"


        time0 = globals()['time0_'+a]
        timef = globals()['timef_'+a]

        ffmpeg_extract_subclip(filename, time0, timef, targetname= "DATA/Test_data/KinectData/S2/S2P32K" + str(i) + "_" + a + ".mp4")
# Out:
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# Moviepy - Running:
# ...

# %%
#ffmpeg_extract_subclip("front_so_1_prediction.mp4", 0, 2, targetname="side_cut.mp4")
ffmpeg_extract_subclip("DATA/Test_data/CRANFIELD_test-data/Dongzi Camera/IMG_3777.mov", 5, 35, targetname="DATA/Test_data/CRANFIELD_test-data/Dongzi Camera/IMG_3777_Trim.mov")
# Out:
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
